# %% [markdown]
# <a href="https://colab.research.google.com/github/sasipriyanka214/Descending-Order-program-using-Python/blob/main/Importing_pandas_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
import pandas as pd

# %%
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
idata={'Age':age,'Height':height,'Weight':weight,'Speed':speed}
idata
# Out:
# {'Age': [43,
#   94,
#   6,
#   49,
#   39,
#   57,
#   4,
#   7,
#   74,
#   0,
#   72,
#   46,
#   37,
#   90,
#   32,
#   9,
#   98,
#   58,
#   64,
#   61,
#   68,
#   56,
#   92,
#   3,
#   51,
#   66,
#   14,
#   49,
#   83,
#   11,
#   8,
#   20,
#   56,
#   68,
#   13,
#   32,
#   51,
#   50,
#   83,
#   4,
#   18,
#   7,
#   31,
#   55,
#   14,
#   97,
#   99,
#   91,
#   86,
#   62,
#   59,
#   82,
#   77,
#   80,
#   73,
#   98,
#   88,
#   58,
#   58,
#   99,
#   86,
#   79,
#   63,
#   52,
#   91,
#   52,
#   68,
#   74,
#   78,
#   53,
#   14,
#   92,
#   35,
#   23,
#   57,
#   43,
#   100,
#   67,
#   52,
#   10,
#   94,
#   80,
#   3,
#   64,
#   59,
#   21,
#   24,
#   99,
#   88,
#   18,
#   70,
#   30,
#   9,
#   86,
#   92,
#   20,
#   22,
#   61,
#   43,
#   21],
#  'Height': [60,
#   88,
#   19,
#   98,
#   100,
#   53,
#   91,
#   99,
#   52,
#   24,
#   25,
#   8,
#   87,
#   72,
#   60,
#   43,
#   27,
#   39,
#   97,
#   49,
#   77,
#   80,
#   27,
#   46,
#   91,
#   98,
#   3,
#   73,
#   69,
#   67,
#   17,
#   11,
#   47,
#   24,
#   45,
#   44,
#   63,
#   82,
#   50,
#   92,
#   66,
#   83,
#   27,
#   6,
#   88,
#   65,
#   16,
#   15,
#   60,
#   85,
#   2,
#   19,
#   57,
#   29,
#   79,
#   43,
#   5,
#   1,
#   41,
#   7,
#   97,
#   6,
#   45,
#   22,
#   67,
#   69,
#   58,
#   75,
#   32,
#   48,
#   63,
#   93,
#   32,
#   3,
#   59,
#   17,
#   12,
#   100,
#   9,
#   37,
#   1,
#   44,
#   55,
#   74,
#   22,
#   20,
#   44,
#   43,
#   99,
#   98,
#   93,
#   21,
#   78,
#   30,
#   91,
#   65,
#   3,
#   96,
#   99,
#   23],
#  'Weight': [80,
#   73,
#   13,
#   4,
#   17,
#   64,
#   91,
#   52,
#   97,
#   65,
#   85,
#   98,
#   86,
#   66,
#   83,
#   54,
#   88,
#   12,
#   70,
#   55,
#   19,
#   69,
#   13,
#   71,
#   91,
#   64,
#   71,
#   46,
#   10,
#   29,
#   98,
#   38,
#   99,
#   36,
#   40,
#   31,
#   1,
#   95,
#   54,
#   48,
#   84,
#   78,
#   48,
#   2,
#   27,
#   9,
#   62,
#   51,
#   61,
#   76,
#   64,
#   72,
#   91,
#   87,
#   68,
#   17,
#   9,
#   4,
#   86,
#   100,
#   95,
#   21,
#   31,
#   39,
#   20,
#   34,
#   6,
#   6,
#   18,
#   71,
#   44,
#   99,
#   16,
#   43,
#   94,
#   89,
#   56,
#   34,
#   58,
#   85,
#   25,
#   85,
#   81,
#   44,
#   19,
#   70,
#   27,
#   74,
#   86,
#   52,
#   90,
#   58,
#   87,
#   91,
#   40,
#   15,
#   38,
#   89,
#   16,
#   66],
#  'Speed': [100,
#   12,
#   69,
#   55,
#   91,
#   13,
#   51,
#   34,
#   8,
#   21,
#   78,
#   38,
#   23,
#   19,
#   13,
#   58,
#   99,
#   11,
#   41,
#   22,
#   45,
#   60,
#   21,
#   16,
#   46,
#   20,
#   99,
#   30,
#   13,
#   67,
#   31,
#   71,
#   33,
#   94,
#   63,
#   37,
#   89,
#   29,
#   46,
#   17,
#   20,
#   11,
#   65,
#   32,
#   97,
#   15,
#   7,
#   33,
#   78,
#   79,
#   95,
#   53,
#   54,
#   46,
#   44,
#   31,
#   36,
#   23,
#   40,
#   1,
#   4,
#   57,
#   97,
#   98,
#   62,
#   58,
#   20,
#   63,
#   79,
#   4,
#   64,
#   42,
#   45,
#   5,
#   93,
#   50,
#   37,
#   34,
#   19,
#   6,
#   87,
#   89,
#   73,
#   2,
#   57,
#   62,
#   1,
#   45,
#   5,
#   19,
#   36,
#   68,
#   57,
#   9,
#   29,
#   66,
#   48,
#   81,
#   4,
#   70]}

# %%
df1=pd.DataFrame(idata)
df1
# Out:
#     Age  Height  Weight  Speed
# 0    43      60      80    100
# 1    94      88      73     12
# 2     6      19      13     69
# 3    49      98       4     55
# 4    39     100      17     91
# ..  ...     ...     ...    ...
# 95   20      65      15     66
# 96   22       3      38     48
# 97   61      96      89     81
# 98   43      99      16      4
# 99   21      23      66     70
#
# [100 rows x 4 columns]

# %%
df1.tail(10)
# Out:
#     Age  Height  Weight  Speed
# 90   70      93      90     36
# 91   30      21      58     68
# 92    9      78      87     57
# 93   86      30      91      9
# 94   92      91      40     29
# 95   20      65      15     66
# 96   22       3      38     48
# 97   61      96      89     81
# 98   43      99      16      4
# 99   21      23      66     70

# %%
df1["Age"]
# Out:
# 0     43
# 1     94
# 2      6
# 3     49
# 4     39
#       ..
# 95    20
# 96    22
# 97    61
# 98    43
# 99    21
# Name: Age, Length: 100, dtype: int64

# %%
df1[["Age","Height"]]
# Out:
#     Age  Height
# 0    43      60
# 1    94      88
# 2     6      19
# 3    49      98
# 4    39     100
# ..  ...     ...
# 95   20      65
# 96   22       3
# 97   61      96
# 98   43      99
# 99   21      23
#
# [100 rows x 2 columns]

# %%
df1.loc[0:3,['Age','Height']]
# Out:
#    Age  Height
# 0   43      60
# 1   94      88
# 2    6      19
# 3   49      98

# %%
df2=df1[['Age','Height']]
df2.describe()
# Out:
#               Age      Height
# count  100.000000  100.000000
# mean    53.430000   51.340000
# std     30.033401   31.153001
# min      0.000000    1.000000
# 25%     23.750000   23.750000
# 50%     57.000000   49.500000
# 75%     79.250000   78.250000
# max    100.000000  100.000000

# %%
df1.sort_index()
# Out:
#     Age  Height  Weight  Speed
# 0    43      60      80    100
# 1    94      88      73     12
# 2     6      19      13     69
# 3    49      98       4     55
# 4    39     100      17     91
# ..  ...     ...     ...    ...
# 95   20      65      15     66
# 96   22       3      38     48
# 97   61      96      89     81
# 98   43      99      16      4
# 99   21      23      66     70
#
# [100 rows x 4 columns]

# %%
df1.sort_index(ascending=False)
# Out:
#     Age  Height  Weight  Speed
# 99   21      23      66     70
# 98   43      99      16      4
# 97   61      96      89     81
# 96   22       3      38     48
# 95   20      65      15     66
# ..  ...     ...     ...    ...
# 4    39     100      17     91
# 3    49      98       4     55
# 2     6      19      13     69
# 1    94      88      73     12
# 0    43      60      80    100
#
# [100 rows x 4 columns]

# %%
df1.sort_index(ascending=True)
# Out:
#     Age  Height  Weight  Speed
# 0    43      60      80    100
# 1    94      88      73     12
# 2     6      19      13     69
# 3    49      98       4     55
# 4    39     100      17     91
# ..  ...     ...     ...    ...
# 95   20      65      15     66
# 96   22       3      38     48
# 97   61      96      89     81
# 98   43      99      16      4
# 99   21      23      66     70
#
# [100 rows x 4 columns]

# %%
df2[0::2]
# Out:
#     Age  Height
# 0    43      60
# 2     6      19
# 4    39     100
# 6     4      91
# 8    74      52
# 10   72      25
# 12   37      87
# 14   32      60
# 16   98      27
# 18   64      97
# 20   68      77
# 22   92      27
# 24   51      91
# 26   14       3
# 28   83      69
# 30    8      17
# 32   56      47
# 34   13      45
# 36   51      63
# 38   83      50
# 40   18      66
# 42   31      27
# 44   14      88
# 46   99      16
# 48   86      60
# 50   59       2
# 52   77      57
# 54   73      79
# 56   88       5
# 58   58      41
# 60   86      97
# 62   63      45
# 64   91      67
# 66   68      58
# 68   78      32
# 70   14      63
# 72   35      32
# 74   57      59
# 76  100      12
# 78   52       9
# 80   94       1
# 82    3      55
# 84   59      22
# 86   24      44
# 88   88      99
# 90   70      93
# 92    9      78
# 94   92      91
# 96   22       3
# 98   43      99

# %%
df2[0::2].describe()
# Out:
#               Age      Height
# count   50.000000   50.000000
# mean    54.780000   52.140000
# std     30.116298   30.843919
# min      3.000000    1.000000
# 25%     31.250000   27.000000
# 50%     58.500000   56.000000
# 75%     81.750000   77.750000
# max    100.000000  100.000000

# %%
df1['weight']>50
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weight'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-bd91ecd02415> in <cell line: 0>()
# ----> 1 df1['weight']>50
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'weight'

# %%
filter1=df1['Weight']>50
filter1
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97     True
# 98    False
# 99     True
# Name: Weight, Length: 100, dtype: bool

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 0    43      60      80    100
# 1    94      88      73     12
# 5    57      53      64     13
# 6     4      91      91     51
# 7     7      99      52     34
# 8    74      52      97      8
# 9     0      24      65     21
# 10   72      25      85     78
# 11   46       8      98     38
# 12   37      87      86     23
# 13   90      72      66     19
# 14   32      60      83     13
# 15    9      43      54     58
# 16   98      27      88     99
# 18   64      97      70     41
# 19   61      49      55     22
# 21   56      80      69     60
# 23    3      46      71     16
# 24   51      91      91     46
# 25   66      98      64     20
# 26   14       3      71     99
# 30    8      17      98     31
# 32   56      47      99     33
# 37   50      82      95     29
# 38   83      50      54     46
# 40   18      66      84     20
# 41    7      83      78     11
# 46   99      16      62      7
# 47   91      15      51     33
# 48   86      60      61     78
# 49   62      85      76     79
# 50   59       2      64     95
# 51   82      19      72     53
# 52   77      57      91     54
# 53   80      29      87     46
# 54   73      79      68     44
# 58   58      41      86     40
# 59   99       7     100      1
# 60   86      97      95      4
# 69   53      48      71      4
# 71   92      93      99     42
# 74   57      59      94     93
# 75   43      17      89     50
# 76  100      12      56     37
# 78   52       9      58     19
# 79   10      37      85      6
# 81   80      44      85     89
# 82    3      55      81     73
# 85   21      20      70     62
# 87   99      43      74     45
# 88   88      99      86      5
# 89   18      98      52     19
# 90   70      93      90     36
# 91   30      21      58     68
# 92    9      78      87     57
# 93   86      30      91      9
# 97   61      96      89     81
# 99   21      23      66     70

# %%
filter2=df1['Age']>50
filter2
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97     True
# 98    False
# 99    False
# Name: Age, Length: 100, dtype: bool

# %%
df1[filter1&filter2]
# Out:
#     Age  Height  Weight  Speed
# 1    94      88      73     12
# 5    57      53      64     13
# 8    74      52      97      8
# 10   72      25      85     78
# 13   90      72      66     19
# 16   98      27      88     99
# 18   64      97      70     41
# 19   61      49      55     22
# 21   56      80      69     60
# 24   51      91      91     46
# 25   66      98      64     20
# 32   56      47      99     33
# 38   83      50      54     46
# 46   99      16      62      7
# 47   91      15      51     33
# 48   86      60      61     78
# 49   62      85      76     79
# 50   59       2      64     95
# 51   82      19      72     53
# 52   77      57      91     54
# 53   80      29      87     46
# 54   73      79      68     44
# 58   58      41      86     40
# 59   99       7     100      1
# 60   86      97      95      4
# 69   53      48      71      4
# 71   92      93      99     42
# 74   57      59      94     93
# 76  100      12      56     37
# 78   52       9      58     19
# 81   80      44      85     89
# 87   99      43      74     45
# 88   88      99      86      5
# 90   70      93      90     36
# 93   86      30      91      9
# 97   61      96      89     81

# %%
df1.loc[filter1&filter2]
# Out:
#     Age  Height  Weight  Speed
# 1    94      88      73     12
# 5    57      53      64     13
# 8    74      52      97      8
# 10   72      25      85     78
# 13   90      72      66     19
# 16   98      27      88     99
# 18   64      97      70     41
# 19   61      49      55     22
# 21   56      80      69     60
# 24   51      91      91     46
# 25   66      98      64     20
# 32   56      47      99     33
# 38   83      50      54     46
# 46   99      16      62      7
# 47   91      15      51     33
# 48   86      60      61     78
# 49   62      85      76     79
# 50   59       2      64     95
# 51   82      19      72     53
# 52   77      57      91     54
# 53   80      29      87     46
# 54   73      79      68     44
# 58   58      41      86     40
# 59   99       7     100      1
# 60   86      97      95      4
# 69   53      48      71      4
# 71   92      93      99     42
# 74   57      59      94     93
# 76  100      12      56     37
# 78   52       9      58     19
# 81   80      44      85     89
# 87   99      43      74     45
# 88   88      99      86      5
# 90   70      93      90     36
# 93   86      30      91      9
# 97   61      96      89     81

# %%
df1[filter1|filter2]
# Out:
#     Age  Height  Weight  Speed
# 0    43      60      80    100
# 1    94      88      73     12
# 5    57      53      64     13
# 6     4      91      91     51
# 7     7      99      52     34
# ..  ...     ...     ...    ...
# 92    9      78      87     57
# 93   86      30      91      9
# 94   92      91      40     29
# 97   61      96      89     81
# 99   21      23      66     70
#
# [82 rows x 4 columns]
